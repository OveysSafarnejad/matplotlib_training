# %%
from matplotlib import pyplot as plt

# %%
# plt.style.available

# %%
ages = list(range(25,35))
py_sal = list((40_900., 41000, 46_000, 49_000, 59_000, 63_300, 65_000, 70_000, 76_000, 89_000))
js_sal = list((29_900., 34_000, 37_000, 41_000, 50_000, 55_300, 59_000, 65_000, 70_000, 75_000))

# plt.style.use('fivethirtyeight')

plt.plot(ages, py_sal, color='#5a7d9a', linestyle='--', marker='o', linewidth=2, label='python developers')
plt.plot(ages, js_sal, color='g', linestyle='-', label='JS developers')

plt.legend()
# plt.grid(True)
plt.tight_layout()
plt.xlabel('Ages')
plt.ylabel('Median salary (Euro)')
plt.title('Median salary based on age') 

plt.savefig('developers_plot.png')
# plt.xkcd() # something like handdrawn plot
